# %%
import pandas as pd
df = pd.read_excel(r'E:\Personal\iNeuron\data fsds\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration PatternType  \
# 0      sleevless    empire            NaN     chiffon     ruffles      animal
# ...

# %%
import pandas as pd
df1 = pd.read_excel(r'E:\Personal\iNeuron\data fsds\Dress Sales.xlsx')
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
import mysql.connector as connection

mydb = connection.connect(host="localhost", database = 'mysql',user="root", passwd="mysql",use_pure=True)
query = "CREATE TABLE mysql.Attribute_Data (Dress_ID int, Style varchar(20), Price varchar(25), Rating decimal(5,2), Size varchar(25), Season varchar(25), NeckLine varchar(25), SleeveLength varchar(25), Waiseline varchar(25), Material varchar(25), FabricType varchar(25), Decoration varchar(25), PatternType varchar(25), Recommendation INT(2))"
cursor = mydb.cursor()
cursor.execute(query)
print("Table created")
mydb.close()
# Out:
# Table created

# %%
import mysql.connector as connection

mydb = connection.connect(host="localhost", database = 'mysql',user="root", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
cols = ','.join([str(i) for i in df.columns.tolist()])
print("cols::", cols)
for i,row in df.iterrows():
    #print(tuple(row))
    sql = "INSERT INTO mysql.Attribute_Data (" +cols + ") VALUES (" + "%s,"*(len(row)-1) + "%s)"
    print(sql)
    cursor.execute(sql, tuple(row))
    print("bulk insert of data has been done ")
mydb.commit()
# Out:
# cols:: Dress_ID,Style,Price,Rating,Size,Season,NeckLine,SleeveLength,waiseline,Material,FabricType,Decoration,PatternType,Recommendation
# INSERT INTO mysql.Attribute_Data (Dress_ID,Style,Price,Rating,Size,Season,NeckLine,SleeveLength,waiseline,Material,FabricType,Decoration,PatternType,Recommendation) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# bulk insert of data has been done
# INSERT INTO mysql.Attribute_Data (Dress_ID,Style,Price,Rating,Size,Season,NeckLine,SleeveLength,waiseline,Material,FabricType,Decoration,PatternType,Recommendation) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# bulk insert of data has been done
# INSERT INTO mysql.Attribute_Data (Dress_ID,Style,Price,Rating,Size,Season,NeckLine,SleeveLength,waiseline,Material,FabricType,Decoration,PatternType,Recommendation) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
# bulk insert of data has been done
# ...

# %%
import json
js = df.to_json(orient='index')
jsondict = json.loads(js)
for key in jsondict:
    print(key)
    print(jsondict[key])
# Out:
# 0
# {'Dress_ID': 1006032852, 'Style': 'Sexy', 'Price': 'Low', 'Rating': 4.6, 'Size': 'M', 'Season': 'Summer', 'NeckLine': 'o-neck', 'SleeveLength': 'sleevless', 'waiseline': 'empire', 'Material': None, 'FabricType': 'chiffon', 'Decoration': 'ruffles', 'PatternType': 'animal', 'Recommendation': 1}
# 1
# {'Dress_ID': 1212192089, 'Style': 'Casual', 'Price': 'Low', 'Rating': 0.0, 'Size': 'L', 'Season': 'Summer', 'NeckLine': 'o-neck', 'SleeveLength': 'Petal', 'waiseline': 'natural', 'Material': 'microfiber', 'FabricType': None, 'Decoration': 'ruffles', 'PatternType': 'animal', 'Recommendation': 0}
# 2
# {'Dress_ID': 1190380701, 'Style': 'vintage', 'Price': 'High', 'Rating': 0.0, 'Size': 'L', 'Season': 'Automn', 'NeckLine': 'o-neck', 'SleeveLength': 'full', 'waiseline': 'natural', 'Material': 'polyster', 'FabricType': None, 'Decoration': None, 'PatternType': 'print', 'Recommendation': 0}
# 3
# ...

# %%
import json
df.to_json("July_24th.json")
client = pymongo.MongoClient("mongodb+srv://kishor_ineuron:mongodb123@cluster0.yk4yr.mongodb.net/?retryWrites=true&w=majority")
db = client.test
with open('July_24th.json') as f:
    data = json.load(f)
db1 = client['mongotest']
collection = db1['24thJuly']
collection.insert_one(data)

# %%
#6. in sql task try to perform left join operation with attribute dataset and dress dataset on column Dress_ID

SELECT Attribute_Data.Dress_ID, Attribute_Data.style, Attribute_Data.price, Attribute_Data.Rating, Attribute_Data.size
FROM Attribute_Data
LEFT JOIN Dress_Sales  
ON Dress_Sales.Dress_ID = Dress_Sales.Dress_ID;
